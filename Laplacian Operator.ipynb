# %%
import cv2 as cv
import matplotlib.pyplot as plt
import sys
import numpy as np 

img = cv.imread(cv.samples.findFile("./Images/DIP3E_Original_Images_CH03/Fig0333(a)(test_pattern_blurring_orig).tif"),  cv.IMREAD_COLOR)

plt.imshow(img)
plt.title("Display Window")
plt.axis('off')  # Hide axes
plt.show()

# %%
ddepth = -1
ind = 0

kernel = np.array([[0, 1, 0],
                   [1, -4, 0],
                   [1, 0, 1]], np.float32)

filtered_image = cv.filter2D(img, -1, kernel)


plt.imshow(filtered_image)
plt.title("Display Window")
plt.axis('off')  # Hide axes
plt.show()
